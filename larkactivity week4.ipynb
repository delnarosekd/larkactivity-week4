# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv(r"C:\Users\DELNA ROSE\Downloads\Telco-Customer-Churn.xlsx - Telco-Customer-Churn.csv")
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # 1. Compare Churn count with respect to gender

# %%
import seaborn as sns
sns.countplot(data['gender'], hue= data['Churn'])
plt.title("Churn count vs Gender",fontsize=20)
# Out:
# F:\ANACONDA\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 2. Find out how many female senior citizens there in the dataset

# %%
female_senior=data[(data['gender']=='Female')& (data['SeniorCitizen']==1)]
female_senior
sns.countplot(x=female_senior['gender'])
plt.title("Female senior citizens",fontsize=20,fontweight='bold')
plt.figure(figsize=(10,20))

# %% [markdown]
# # 3. Compare Tenure with Total charges

# %%
plt.figure(figsize=(8,8))
plt.scatter(data['tenure'],data['TotalCharges'],marker='*')
plt.title("Tenure vs Total charges",fontsize=20)
plt.xlabel("Tenure")
plt.ylabel("Totalcharges")
# Out:
# Text(0, 0.5, 'Totalcharges')

# %% [markdown]
# # 4. Find out which contract is preferred by the senior citizen

# %%
senior=data[data['SeniorCitizen']==1]
senior
sns.countplot(x=senior['Contract'])
plt.title("Contract preferred by the seniorcitizens",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Contract preferred by the seniorcitizens')

# %% [markdown]
# # 5. Comment on your findings on payment method

# %%
sns.countplot(data['PaymentMethod'],hue= data['Contract'])
plt.title("Paymentmethod : Contract",fontsize=20)
plt.xticks(rotation=10)
# Out:
# F:\ANACONDA\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Electronic check'),
#   Text(1, 0, 'Mailed check'),
#   Text(2, 0, 'Bank transfer (automatic)'),
#   Text(3, 0, 'Credit card (automatic)')])

# %%
sns.countplot(x=data['PaymentMethod'],hue= data['gender'])
plt.title(" Paymentmethod : gender",fontsize=20)
plt.xticks(rotation=10)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Electronic check'),
#   Text(1, 0, 'Mailed check'),
#   Text(2, 0, 'Bank transfer (automatic)'),
#   Text(3, 0, 'Credit card (automatic)')])

# %%
sns.countplot(x=data['PaymentMethod'],hue= data['SeniorCitizen'])
plt.title(" Paymentmethod :SeniorCitizen",fontsize=20)
plt.xticks(rotation=10)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Electronic check'),
#   Text(1, 0, 'Mailed check'),
#   Text(2, 0, 'Bank transfer (automatic)'),
#   Text(3, 0, 'Credit card (automatic)')])
